# %%
#first of all, we need plotly 
pip install plotly

# %%
#I wanted to make plotly charts out of my pandas dataframe
import pandas as pd

# %%
#the plotly charts are displayed using HTML from the ipython library
from IPython.display import HTML
import plotly.express as px

# %%
df=pd.read_csv("/content/wdi_data (1).csv")
df #
# Out:
#     Unnamed: 0  Year  ...         Income Group    Lending Type
# 0            0  2010  ...  Upper middle income            IBRD
# 1            1  2011  ...  Upper middle income            IBRD
# 2            2  2012  ...  Upper middle income            IBRD
# 3            3  2013  ...  Upper middle income            IBRD
# 4            4  2014  ...  Upper middle income            IBRD
# ..         ...   ...  ...                  ...             ...
# 63          63  2012  ...          High income  Not classified
# 64          64  2013  ...          High income  Not classified
# 65          65  2014  ...          High income  Not classified
# 66          66  2015  ...          High income  Not classified
# 67          67  2016  ...          High income  Not classified
#
# [68 rows x 10 columns]

# %% [markdown]
# # **CO2 EMISSIONS OF TOP ECONOMIES DURING 2010 TO 2018**

# %%
fig = px.line(df, x="Year", y="EN.ATM.CO2E.KT", color="Country Name");
fig.show();
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="63a2925c-0915-4258-9503-17f352cbc097" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("63a2925c-0915-4258-9503-17f352cbc097")) {
#                     Plotly.newPlot(
#                         '63a2925c-0915-4258-9503-17f352cbc097',
# ...

# %%
df_ghg=pd.read_csv("/content/ghg-table.csv")
df_ghg
# Out:
#     Unnamed: 0  Year  ...         Income Group    Lending Type
# 0            0  2010  ...  Upper middle income            IBRD
# 1            1  2011  ...  Upper middle income            IBRD
# 2            2  2012  ...  Upper middle income            IBRD
# 3            3  2010  ...  Upper middle income            IBRD
# 4            4  2011  ...  Upper middle income            IBRD
# 5            5  2012  ...  Upper middle income            IBRD
# 6            6  2010  ...          High income  Not classified
# 7            7  2011  ...          High income  Not classified
# 8            8  2012  ...          High income  Not classified
# 9            9  2010  ...          High income  Not classified
# 10          10  2011  ...          High income  Not classified
# 11          11  2012  ...          High income  Not classified
# 12          12  2010  ...  Lower middle income            IBRD
# 13          13  2011  ...  Lower middle income            IBRD
# ...

# %% [markdown]
# # **OTHER GREEN HOUSE GAS EMISSIONS OF TOP ECONOMIES DURING 2010 TO 2018**

# %%
fig = px.choropleth(df_ghg, locations="Country Code",
                    color="EN.ATM.GHGO.KT.CE", 
                    hover_name="Country Name", 
                    color_continuous_scale=px.colors.sequential.Plasma)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="45de4d54-f781-4164-94cb-381c35de290c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("45de4d54-f781-4164-94cb-381c35de290c")) {
#                     Plotly.newPlot(
#                         '45de4d54-f781-4164-94cb-381c35de290c',
# ...

# %%
df_co2_gdp=pd.read_csv("/content/co2kg.csv")

# %%
df_co2_gdp
# Out:
#     Unnamed: 0  Year  ...         Income Group    Lending Type
# 0            0  2010  ...  Upper middle income            IBRD
# 1            1  2011  ...  Upper middle income            IBRD
# 2            2  2012  ...  Upper middle income            IBRD
# 3            3  2013  ...  Upper middle income            IBRD
# 4            4  2014  ...  Upper middle income            IBRD
# ..         ...   ...  ...                  ...             ...
# 63          63  2012  ...          High income  Not classified
# 64          64  2013  ...          High income  Not classified
# 65          65  2014  ...          High income  Not classified
# 66          66  2015  ...          High income  Not classified
# 67          67  2016  ...          High income  Not classified
#
# [68 rows x 10 columns]

# %% [markdown]
# # **CO2 EMISSIONS EQUIVALENT TO PPP GDP OF TOP ECONOMIES**

# %%
fig = px.line(df_co2_gdp, x="Year", y="EN.ATM.CO2E.KD.GD", color="Country Name");
fig.show();
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="da153d76-e3c1-421c-a023-97ae6823f770" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("da153d76-e3c1-421c-a023-97ae6823f770")) {
#                     Plotly.newPlot(
#                         'da153d76-e3c1-421c-a023-97ae6823f770',
# ...

# %%
df_gdp_annual=pd.read_csv("/content/wdi_data (3).csv")

# %%
df_gdp_annual
# Out:
#     Unnamed: 0  Year  ...         Income Group    Lending Type
# 0            0  2010  ...  Upper middle income            IBRD
# 1            1  2011  ...  Upper middle income            IBRD
# 2            2  2012  ...  Upper middle income            IBRD
# 3            3  2013  ...  Upper middle income            IBRD
# 4            4  2014  ...  Upper middle income            IBRD
# ..         ...   ...  ...                  ...             ...
# 95          95  2015  ...          High income  Not classified
# 96          96  2016  ...          High income  Not classified
# 97          97  2017  ...          High income  Not classified
# 98          98  2018  ...          High income  Not classified
# 99          99  2019  ...          High income  Not classified
#
# [100 rows x 10 columns]

# %% [markdown]
# # **GDP (ANNUAL) OF TOP ECONOMIES FROM 2010 TO 2018**

# %%
fig = px.line(df_gdp_annual, x="Year", y="NY.GDP.MKTP.KD.ZG", color="Country Name");
fig.show();
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d0a91d63-3b82-497c-8395-4de99e7170e0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d0a91d63-3b82-497c-8395-4de99e7170e0")) {
#                     Plotly.newPlot(
#                         'd0a91d63-3b82-497c-8395-4de99e7170e0',
# ...

# %%
df_gdp_final=pd.read_csv("/content/wdi_data (4).csv")

# %%
df_gdp_final
# Out:
#     Unnamed: 0  Year  ...         Income Group    Lending Type
# 0            0  2010  ...  Upper middle income            IBRD
# 1            1  2011  ...  Upper middle income            IBRD
# 2            2  2012  ...  Upper middle income            IBRD
# 3            3  2013  ...  Upper middle income            IBRD
# 4            4  2014  ...  Upper middle income            IBRD
# ..         ...   ...  ...                  ...             ...
# 95          95  2015  ...          High income  Not classified
# 96          96  2016  ...          High income  Not classified
# 97          97  2017  ...          High income  Not classified
# 98          98  2018  ...          High income  Not classified
# 99          99  2019  ...          High income  Not classified
#
# [100 rows x 10 columns]

# %% [markdown]
# # **GDP (PPP) OF TOP ECONOMIES IN THE TIMESPAN 2010 TO 2018**

# %%
fig = px.bar(df_gdp_final, y='NY.GDP.MKTP.PP.CD', x='Country Name', color="Country Code")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a380c946-19bc-45bf-8877-c48204b05641" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a380c946-19bc-45bf-8877-c48204b05641")) {
#                     Plotly.newPlot(
#                         'a380c946-19bc-45bf-8877-c48204b05641',
# ...

# %%
df_bubble=pd.read_csv("/content/wdi_data (5).csv")

# %%
df_bubble
# Out:
#     Unnamed: 0  Year  ...         Income Group    Lending Type
# 0            0  2015  ...  Upper middle income            IBRD
# 1            1  2016  ...  Upper middle income            IBRD
# 2            2  2015  ...  Upper middle income            IBRD
# 3            3  2016  ...  Upper middle income            IBRD
# 4            4  2015  ...          High income  Not classified
# 5            5  2016  ...          High income  Not classified
# 6            6  2015  ...  Lower middle income            IBRD
# 7            7  2016  ...  Lower middle income            IBRD
# 8            8  2015  ...  Upper middle income            IBRD
# 9            9  2016  ...  Upper middle income            IBRD
# 10          10  2015  ...          High income  Not classified
# 11          11  2016  ...          High income  Not classified
# 12          12  2015  ...  Upper middle income            IBRD
# 13          13  2016  ...  Upper middle income            IBRD
# ...

# %% [markdown]
# # **THIS BUBBLE CHART SHOWS THAT TOP ECONOMIES ARE THE COUNTRIES THAT HAVE HIGHEST CARBON EMISSIONS AND ALSO HAVE EXCEEDED WHO'S AIR POLLUTION GUIDELINES IN THE TIME SPAN 2010 TO 2018**

# %%
fig = px.scatter(df_bubble.query("Year==2014"), x="NY.GDP.PCAP.PP.CD", y="lifeExp",
	         size="pop", color="continent",
                 hover_name="country", log_x=True, size_max=60)
fig.show()

# %% [markdown]
# ![newplot.png](data:image/png;base64,...)

# %% [markdown]
# # **CONCLUSION:**
#
# # **These 6 charts are indicative of the below conclusion:**
#
# # During the time span 2010-2018, according to the GDP line charts in this project, the world's top economies were United states, China, India, Brazil, Russia, Germany, Japan, UK, France, Indonesia. Shockingly, the same countries caused the most CO2 and GHG emissions during the same time span.
#
# # **Note**: I would like to acknowledge a point here, "Corelation is not causation". There might be several other factors that indicate exact causation for climate change. But here is my effort in showing that we cannot for sure neglect the fact that developing/developed countries with stable economies are a huge part of Global warming and climate change.
#
# # ***Thankyou!***
